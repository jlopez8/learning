# %% [markdown]
# # Vectorization

# %%
import numpy as np

a = np.array([1, 2, 3, 4])
print(a)
# Out:
# [1 2 3 4]

# %%
import time # for timing operations

m = 10 #1000000
a = np.random.rand(m)
# Another random array.
b = np.random.rand(m) 

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print("Value: ", c)
print("Vectorized version: " + str(1000*(toc - tic)) + "ms")

c = 0
tic = time.time()
for i in range(m):
    c += a[i]*b[i]
toc = time.time()

print("Value: ", c)
print("For loop: " + str(1000*(toc - tic)) + "ms")
# Out:
# Value:  250016.38833624762
# Vectorized version: 1.4848709106445312ms
# Value:  250016.3883362471
# For loop: 365.07391929626465ms
